# %%
pip install gspread
# Out:
# Requirement already satisfied: gspread in c:\users\suman kumar\anaconda3\lib\site-packages (5.7.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\suman kumar\anaconda3\lib\site-packages (from gspread) (0.7.1)
# Requirement already satisfied: google-auth>=1.12.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from gspread) (2.14.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\suman kumar\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\suman kumar\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (4.9)
# Requirement already satisfied: six>=1.9.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from google-auth>=1.12.0->gspread) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\suman kumar\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.12.0->gspread) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.26.7)
#
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\suman kumar\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2)

# %%
import gspread as gs
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes = True)
# %matplotlib inline

# %%
#establish the connection
gc = gs.service_account("my.json")
wks = gc.open("Copy of BSE500").sheet1
wks
# Out:
# <Worksheet 'bse500' id:1547461811>

# %%
sheet_name = 'Copy of BSE500'
tab_name = 'bse500'
def get_sheet_data(sheet_name,tab_name):
    gc = gs.service_account(filename="C:/Users/Suman Kumar/Dropbox/PC/Downloads/my.json")
    sh = gc.open(sheet_name)
    worksheet=sh.worksheet(tab_name)
    df=pd.DataFrame(worksheet.get_all_records())
    return df

df = get_sheet_data(sheet_name,tab_name)
df
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# 0    INE058A01010        Healthcare                 Drugs & Pharma
# 1    INE761H01022          Textiles             Readymade Garments
# 2    INE179A01014  Consumer Staples  Household & Personal Products
# 3    INE358A01014        Healthcare                 Drugs & Pharma
# 4    INE323A01026        Automobile               Auto Ancillaries
# ..            ...               ...                            ...
# 496  INE274F01020          Services                    Restaurants
# 497  INE049B01025        Healthcare                 Drugs & Pharma
# 498  INE528G01035         Financial                        Banking
# 499  INE758T01015          Services                     E-Commerce
# 500  IN9155A01020        Automobile            Commercial Vehicles
#
#            Date     Price  1 day change(%)  52 Week Low  ...  \
# 0    2022-09-05   6158.70             0.59      6086.30  ...
# 1    2022-09-05  49786.20            -0.26     31500.00  ...
# 2    2022-09-05  14125.65             0.24     12801.00  ...
# 3    2022-09-05  18209.00            -1.26     15514.00  ...
# 4    2022-09-05  17591.10             0.13     12932.45  ...
# ..          ...       ...              ...          ...  ...
# 496  2022-09-05    650.05             0.82       402.30  ...
# 497  2022-09-05    242.70             3.01       201.50  ...
# 498  2022-09-05     16.65             2.78        10.80  ...
# 499  2022-09-05     59.65            -0.17        40.60  ...
# 500  2022-09-05    227.80            -0.96       137.50  ...
#
#      Price earnings to growth Dividend Yield(%) EV / EBITDA Price / Sales  \
# 0                        0.49              7.95       16.68          4.98
# 1                        3.63              0.74       51.79         11.75
# 2                       13.56              1.13       52.71          12.1
# 3                        1.81              1.51       30.98          7.73
# 4                        -5.8              1.19       25.04          4.03
# ..                        ...               ...         ...           ...
# 496                      3.85              0.00       34.06          7.81
# 497                                        0.00        20.5          1.18
# 498                     15.58              0.00       23.87          2.13
# 499                                        0.00      -40.17         10.71
# 500                                        0.00
#
#     Price / Cash Flow  Earning Per Share  Book Value Per Share  \
# 0               25.39             425.09                631.65
# 1              169.84             656.83               1161.63
# 2               53.17             177.37                227.22
# 3               40.84             380.52                1403.0
# 4              192.66             438.11               3734.33
# ..                ...                ...                   ...
# 496             59.43               3.55                 30.99
# 497              8.48              -20.7                260.73
# 498              1.77               0.47                 13.61
# 499            -73.58              -1.21                 23.01
# 500
#
#      Cash Flow Per Share Free Cash Flow Per Share  Dividend Per Share
# 0                 242.96                   459.22               490.0
# 1                 293.09                   191.03               370.0
# 2                  265.9                   270.47               315.0
# 3                 445.96                    446.9               275.0
# 4                  91.29                    46.68               210.0
# ..                   ...                      ...                 ...
# 496                10.94                     1.29                 0.0
# 497                28.68                     8.54                 0.0
# 498                 9.42                     7.86                 0.0
# 499                -0.91                    -1.16                 0.0
# 500
#
# [501 rows x 41 columns]

# %%
df.dtypes
# Out:
# Company                      object
# BSE code                      int64
# NSE code                     object
# ISIN                         object
# Sector                       object
# Industry                     object
# Date                         object
# Price                       float64
# 1 day change(%)             float64
# 52 Week Low                 float64
# 52 Week High                float64
# 3 Year Low                   object
# 3 Year High                  object
# 5 Year Low                   object
# 5 Year High                  object
# All Time Low                float64
# All Time High               float64
# Market Cap(Cr)              float64
# Enterprise Value(Cr)         object
# 1-Week Return               float64
# 1-Month Return              float64
# 3-Month Return(%)           float64
# 1-Year Return(%)             object
# 3-Year Return                object
# 5-Year Return(%)             object
# 10-Year Return(%)            object
# Price to Earnings            object
# Median P/E                   object
# Price to Book                object
# Median P/B                   object
# Earning Yield(%)            float64
# Price earnings to growth     object
# Dividend Yield(%)           float64
# EV / EBITDA                  object
# Price / Sales                object
# Price / Cash Flow            object
# Earning Per Share            object
# Book Value Per Share         object
# Cash Flow Per Share          object
# Free Cash Flow Per Share     object
# Dividend Per Share           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Company', 'BSE code', 'NSE code', 'ISIN', 'Sector', 'Industry', 'Date',
#        'Price', '1 day change(%)', '52 Week Low', '52 Week High', '3 Year Low',
#        '3 Year High', '5 Year Low', '5 Year High', 'All Time Low',
#        'All Time High', 'Market Cap(Cr)', 'Enterprise Value(Cr)',
#        '1-Week Return', '1-Month Return', '3-Month Return(%)',
#        '1-Year Return(%)', '3-Year Return', '5-Year Return(%)',
#        '10-Year Return(%)', 'Price to Earnings', 'Median P/E', 'Price to Book',
#        'Median P/B', 'Earning Yield(%)', 'Price earnings to growth',
#        'Dividend Yield(%)', 'EV / EBITDA', 'Price / Sales',
#        'Price / Cash Flow', 'Earning Per Share', 'Book Value Per Share',
#        'Cash Flow Per Share', 'Free Cash Flow Per Share',
#        'Dividend Per Share'],
#       dtype='object')

# %%
for i in df.columns:
    df[i]=pd.to_numeric(df[i],errors="ignore")

# %%
df.dtypes
# Out:
# Company                      object
# BSE code                      int64
# NSE code                     object
# ISIN                         object
# Sector                       object
# Industry                     object
# Date                         object
# Price                       float64
# 1 day change(%)             float64
# 52 Week Low                 float64
# 52 Week High                float64
# 3 Year Low                  float64
# 3 Year High                 float64
# 5 Year Low                  float64
# 5 Year High                 float64
# All Time Low                float64
# All Time High               float64
# Market Cap(Cr)              float64
# Enterprise Value(Cr)        float64
# 1-Week Return               float64
# 1-Month Return              float64
# 3-Month Return(%)           float64
# 1-Year Return(%)            float64
# 3-Year Return               float64
# 5-Year Return(%)            float64
# 10-Year Return(%)           float64
# Price to Earnings           float64
# Median P/E                  float64
# Price to Book               float64
# Median P/B                  float64
# Earning Yield(%)            float64
# Price earnings to growth    float64
# Dividend Yield(%)           float64
# EV / EBITDA                 float64
# Price / Sales               float64
# Price / Cash Flow           float64
# Earning Per Share           float64
# Book Value Per Share        float64
# Cash Flow Per Share         float64
# Free Cash Flow Per Share    float64
# Dividend Per Share          float64
# dtype: object

# %%
df
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# 0    INE058A01010        Healthcare                 Drugs & Pharma
# 1    INE761H01022          Textiles             Readymade Garments
# 2    INE179A01014  Consumer Staples  Household & Personal Products
# 3    INE358A01014        Healthcare                 Drugs & Pharma
# 4    INE323A01026        Automobile               Auto Ancillaries
# ..            ...               ...                            ...
# 496  INE274F01020          Services                    Restaurants
# 497  INE049B01025        Healthcare                 Drugs & Pharma
# 498  INE528G01035         Financial                        Banking
# 499  INE758T01015          Services                     E-Commerce
# 500  IN9155A01020        Automobile            Commercial Vehicles
#
#            Date     Price  1 day change(%)  52 Week Low  ...  \
# 0    2022-09-05   6158.70             0.59      6086.30  ...
# 1    2022-09-05  49786.20            -0.26     31500.00  ...
# 2    2022-09-05  14125.65             0.24     12801.00  ...
# 3    2022-09-05  18209.00            -1.26     15514.00  ...
# 4    2022-09-05  17591.10             0.13     12932.45  ...
# ..          ...       ...              ...          ...  ...
# 496  2022-09-05    650.05             0.82       402.30  ...
# 497  2022-09-05    242.70             3.01       201.50  ...
# 498  2022-09-05     16.65             2.78        10.80  ...
# 499  2022-09-05     59.65            -0.17        40.60  ...
# 500  2022-09-05    227.80            -0.96       137.50  ...
#
#      Price earnings to growth  Dividend Yield(%)  EV / EBITDA  Price / Sales  \
# 0                        0.49               7.95        16.68           4.98
# 1                        3.63               0.74        51.79          11.75
# 2                       13.56               1.13        52.71          12.10
# 3                        1.81               1.51        30.98           7.73
# 4                       -5.80               1.19        25.04           4.03
# ..                        ...                ...          ...            ...
# 496                      3.85               0.00        34.06           7.81
# 497                       NaN               0.00        20.50           1.18
# 498                     15.58               0.00        23.87           2.13
# 499                       NaN               0.00       -40.17          10.71
# 500                       NaN               0.00          NaN            NaN
#
#      Price / Cash Flow  Earning Per Share  Book Value Per Share  \
# 0                25.39             425.09                631.65
# 1               169.84             656.83               1161.63
# 2                53.17             177.37                227.22
# 3                40.84             380.52               1403.00
# 4               192.66             438.11               3734.33
# ..                 ...                ...                   ...
# 496              59.43               3.55                 30.99
# 497               8.48             -20.70                260.73
# 498               1.77               0.47                 13.61
# 499             -73.58              -1.21                 23.01
# 500                NaN                NaN                   NaN
#
#      Cash Flow Per Share  Free Cash Flow Per Share  Dividend Per Share
# 0                 242.96                    459.22               490.0
# 1                 293.09                    191.03               370.0
# 2                 265.90                    270.47               315.0
# 3                 445.96                    446.90               275.0
# 4                  91.29                     46.68               210.0
# ..                   ...                       ...                 ...
# 496                10.94                      1.29                 0.0
# 497                28.68                      8.54                 0.0
# 498                 9.42                      7.86                 0.0
# 499                -0.91                     -1.16                 0.0
# 500                  NaN                       NaN                 NaN
#
# [501 rows x 41 columns]

# %%
df.shape
# Out:
# (501, 41)

# %%
df.columns
# Out:
# Index(['Company', 'BSE code', 'NSE code', 'ISIN', 'Sector', 'Industry', 'Date',
#        'Price', '1 day change(%)', '52 Week Low', '52 Week High', '3 Year Low',
#        '3 Year High', '5 Year Low', '5 Year High', 'All Time Low',
#        'All Time High', 'Market Cap(Cr)', 'Enterprise Value(Cr)',
#        '1-Week Return', '1-Month Return', '3-Month Return(%)',
#        '1-Year Return(%)', '3-Year Return', '5-Year Return(%)',
#        '10-Year Return(%)', 'Price to Earnings', 'Median P/E', 'Price to Book',
#        'Median P/B', 'Earning Yield(%)', 'Price earnings to growth',
#        'Dividend Yield(%)', 'EV / EBITDA', 'Price / Sales',
#        'Price / Cash Flow', 'Earning Per Share', 'Book Value Per Share',
#        'Cash Flow Per Share', 'Free Cash Flow Per Share',
#        'Dividend Per Share'],
#       dtype='object')

# %%
sheet_name = 'Copy of Income / Expense'
tab_name = 'inex'
def get_sheet_data(sheet_name,tab_name):
    gc = gs.service_account(filename="C:/Users/Suman Kumar/Dropbox/PC/Downloads/my.json")
    sh = gc.open(sheet_name)
    worksheet=sh.worksheet(tab_name)
    df=pd.DataFrame(worksheet.get_all_values())
    return df

df1 = get_sheet_data(sheet_name,tab_name)
df1
# Out:
#                    0                     1               2            3   \
# 0                Date               Account        Category  Subcategory
# 1      3/2/2022 10:11  CUB - online payment            Food
# 2      3/2/2022 10:11  CUB - online payment           Other
# 3      3/1/2022 19:50  CUB - online payment            Food
# 4      3/1/2022 18:56  CUB - online payment  Transportation
# ..                ...                   ...             ...          ...
# 273  11/22/2021 14:16  CUB - online payment            Food
# 274  11/22/2021 14:16  CUB - online payment            Food
# 275  11/21/2021 17:07  CUB - online payment  Transportation
# 276  11/21/2021 15:50  CUB - online payment            Food
# 277  11/21/2021 13:30  CUB - online payment           Other
#
#                      4     5               6     7       8         9        10
# 0                  Note   INR  Income/Expense  Note  Amount  Currency  Account
# 1               Brownie    50         Expense            50       INR       50
# 2      To lended people   300         Expense           300       INR      300
# 3                Dinner    78         Expense            78       INR       78
# 4                 Metro    30         Expense            30       INR       30
# ..                  ...   ...             ...   ...     ...       ...      ...
# 273              Dinner    90         Expense            90       INR       90
# 274  Lunch with company    97         Expense            97       INR       97
# 275              Rapido   130         Expense           130       INR      130
# 276               Lunch   875         Expense           875       INR      875
# 277       Got from gobi  2000          Income          2000       INR     2000
#
# [278 rows x 11 columns]

# %%
df1.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# dtype: object

# %%
df1
# Out:
#                    0                     1               2            3   \
# 0                Date               Account        Category  Subcategory
# 1      3/2/2022 10:11  CUB - online payment            Food
# 2      3/2/2022 10:11  CUB - online payment           Other
# 3      3/1/2022 19:50  CUB - online payment            Food
# 4      3/1/2022 18:56  CUB - online payment  Transportation
# ..                ...                   ...             ...          ...
# 273  11/22/2021 14:16  CUB - online payment            Food
# 274  11/22/2021 14:16  CUB - online payment            Food
# 275  11/21/2021 17:07  CUB - online payment  Transportation
# 276  11/21/2021 15:50  CUB - online payment            Food
# 277  11/21/2021 13:30  CUB - online payment           Other
#
#                      4     5               6     7       8         9        10
# 0                  Note   INR  Income/Expense  Note  Amount  Currency  Account
# 1               Brownie    50         Expense            50       INR       50
# 2      To lended people   300         Expense           300       INR      300
# 3                Dinner    78         Expense            78       INR       78
# 4                 Metro    30         Expense            30       INR       30
# ..                  ...   ...             ...   ...     ...       ...      ...
# 273              Dinner    90         Expense            90       INR       90
# 274  Lunch with company    97         Expense            97       INR       97
# 275              Rapido   130         Expense           130       INR      130
# 276               Lunch   875         Expense           875       INR      875
# 277       Got from gobi  2000          Income          2000       INR     2000
#
# [278 rows x 11 columns]

# %%
for i in df1.columns:
    df1[i]=pd.to_numeric(df1[i],errors='ignore')

# %%
df1.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# dtype: object

# %%
df2 = df1

# %%
df2.head(2)
# Out:
#                0                     1         2            3        4    5   \
# 0            Date               Account  Category  Subcategory     Note  INR
# 1  3/2/2022 10:11  CUB - online payment      Food               Brownie   50
#
#                6     7       8         9        10
# 0  Income/Expense  Note  Amount  Currency  Account
# 1         Expense            50       INR       50

# %%
df2.columns=df2.iloc[0]
df2=df2[1:]
df2
# Out:
# 0                Date               Account        Category Subcategory  \
# 1      3/2/2022 10:11  CUB - online payment            Food
# 2      3/2/2022 10:11  CUB - online payment           Other
# 3      3/1/2022 19:50  CUB - online payment            Food
# 4      3/1/2022 18:56  CUB - online payment  Transportation
# 5      3/1/2022 18:22  CUB - online payment            Food
# ..                ...                   ...             ...         ...
# 273  11/22/2021 14:16  CUB - online payment            Food
# 274  11/22/2021 14:16  CUB - online payment            Food
# 275  11/21/2021 17:07  CUB - online payment  Transportation
# 276  11/21/2021 15:50  CUB - online payment            Food
# 277  11/21/2021 13:30  CUB - online payment           Other
#
# 0                  Note   INR Income/Expense Note Amount Currency Account
# 1               Brownie    50        Expense          50      INR      50
# 2      To lended people   300        Expense         300      INR     300
# 3                Dinner    78        Expense          78      INR      78
# 4                 Metro    30        Expense          30      INR      30
# 5                Snacks    67        Expense          67      INR      67
# ..                  ...   ...            ...  ...    ...      ...     ...
# 273              Dinner    90        Expense          90      INR      90
# 274  Lunch with company    97        Expense          97      INR      97
# 275              Rapido   130        Expense         130      INR     130
# 276               Lunch   875        Expense         875      INR     875
# 277       Got from gobi  2000         Income        2000      INR    2000
#
# [277 rows x 11 columns]

# %%
df2["INR"]=df2["INR"].astype(float)
# Out:
# C:\Users\SUMANK~1\AppData\Local\Temp/ipykernel_24148/2820016589.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["INR"]=df2["INR"].astype(float)

# %%
df2
# Out:
# 0                Date               Account        Category Subcategory  \
# 1      3/2/2022 10:11  CUB - online payment            Food
# 2      3/2/2022 10:11  CUB - online payment           Other
# 3      3/1/2022 19:50  CUB - online payment            Food
# 4      3/1/2022 18:56  CUB - online payment  Transportation
# 5      3/1/2022 18:22  CUB - online payment            Food
# ..                ...                   ...             ...         ...
# 273  11/22/2021 14:16  CUB - online payment            Food
# 274  11/22/2021 14:16  CUB - online payment            Food
# 275  11/21/2021 17:07  CUB - online payment  Transportation
# 276  11/21/2021 15:50  CUB - online payment            Food
# 277  11/21/2021 13:30  CUB - online payment           Other
#
# 0                  Note     INR Income/Expense Note Amount Currency Account
# 1               Brownie    50.0        Expense          50      INR      50
# 2      To lended people   300.0        Expense         300      INR     300
# 3                Dinner    78.0        Expense          78      INR      78
# 4                 Metro    30.0        Expense          30      INR      30
# 5                Snacks    67.0        Expense          67      INR      67
# ..                  ...     ...            ...  ...    ...      ...     ...
# 273              Dinner    90.0        Expense          90      INR      90
# 274  Lunch with company    97.0        Expense          97      INR      97
# 275              Rapido   130.0        Expense         130      INR     130
# 276               Lunch   875.0        Expense         875      INR     875
# 277       Got from gobi  2000.0         Income        2000      INR    2000
#
# [277 rows x 11 columns]

# %%
df2.shape
# Out:
# (277, 11)

# %%
df2
# Out:
# 0                Date               Account        Category Subcategory  \
# 1      3/2/2022 10:11  CUB - online payment            Food
# 2      3/2/2022 10:11  CUB - online payment           Other
# 3      3/1/2022 19:50  CUB - online payment            Food
# 4      3/1/2022 18:56  CUB - online payment  Transportation
# 5      3/1/2022 18:22  CUB - online payment            Food
# ..                ...                   ...             ...         ...
# 273  11/22/2021 14:16  CUB - online payment            Food
# 274  11/22/2021 14:16  CUB - online payment            Food
# 275  11/21/2021 17:07  CUB - online payment  Transportation
# 276  11/21/2021 15:50  CUB - online payment            Food
# 277  11/21/2021 13:30  CUB - online payment           Other
#
# 0                  Note     INR Income/Expense Note Amount Currency Account
# 1               Brownie    50.0        Expense          50      INR      50
# 2      To lended people   300.0        Expense         300      INR     300
# 3                Dinner    78.0        Expense          78      INR      78
# 4                 Metro    30.0        Expense          30      INR      30
# 5                Snacks    67.0        Expense          67      INR      67
# ..                  ...     ...            ...  ...    ...      ...     ...
# 273              Dinner    90.0        Expense          90      INR      90
# 274  Lunch with company    97.0        Expense          97      INR      97
# 275              Rapido   130.0        Expense         130      INR     130
# 276               Lunch   875.0        Expense         875      INR     875
# 277       Got from gobi  2000.0         Income        2000      INR    2000
#
# [277 rows x 11 columns]

# %%
df2.dtypes
# Out:
# 0
# Date               object
# Account            object
# Category           object
# Subcategory        object
# Note               object
# INR               float64
# Income/Expense     object
# Note               object
# Amount             object
# Currency           object
# Account            object
# dtype: object

# %%
# Task 1

# Calculate net income and expense
# Calculate Category wise expenses and update it in google sheet
# Calculate amount the Available_for_investment

# %%
# I used values in INR 
# Net Income

Net_income = df2[df2["Income/Expense"]=="Income"]["INR"].sum()
Net_income
# Out:
# 54754.0

# %%
# Net Expense
Net_expense = df2[df2["Income/Expense"]=="Expense"]["INR"].sum()
Net_expense
# Out:
# 59024.0

# %%
sheet_name = 'Copy of Final Report'

def get_sheet_data(sheet_name):
    gc = gs.service_account(filename="C:/Users/Suman Kumar/Dropbox/PC/Downloads/my.json")
    sh = gc.open(sheet_name)
    worksheet=sh.worksheet("Sheet1")
    worksheet2=sh.worksheet("Sheet2")
    df=pd.DataFrame(worksheet.get_all_values())
    df11=pd.DataFrame(worksheet2.get_all_values())
    return df
    return df11

df3 = get_sheet_data(sheet_name)
df3
# Out:
#    0                         1                 2
# 0
# 1
# 2
# 3
# 4
# 5
# 6                   Net Income             54754
# 7                  Net Expense             59024
# 8
# 9                         Food          24502.48
# 10                       Other             37868
# 11              Transportation            9203.8
# 12                 Social Life           2513.72
# 13                   Household             12188
# 14                     Apparel              3388
# 15                   Education              1400
# 16                      Salary              8000
# 17                   Allowance             14000
# 18                      Beauty               196
# 19                        Gift               115
# 20                  Petty cash                 3
# 21
# 22
# 23    Available for investment             -4270
# 24
# 25
# 26          Investment Profile  High Risk Taking

# %%
# gc = gs.service_account(filename="C:/Users/Suman Kumar/Dropbox/PC/Downloads/my.json")
# sh = gc.open('Copy of Final Report')
# worksheet=sh.worksheet("Sheet1")
# worksheet2=sh.worksheet("Sheet2")
# dfx=pd.DataFrame(worksheet.get_all_values())
# dfy=pd.DataFrame(worksheet2.get_all_values())

# %%
sheet_name = 'Copy of Final Report'
tab_name = 'Sheet1'
def get_sheet_data(sheet_name,tab_name):
    gc = gs.service_account(filename="C:/Users/Suman Kumar/Dropbox/PC/Downloads/my.json")
    sh = gc.open(sheet_name)
    worksheet=sh.worksheet(tab_name)
    df=pd.DataFrame(worksheet.get_all_values())
    return df

df3 = get_sheet_data(sheet_name,tab_name)
df3
# Out:
#    0                         1                 2
# 0
# 1
# 2
# 3
# 4
# 5
# 6                   Net Income             54754
# 7                  Net Expense             59024
# 8
# 9                         Food          24502.48
# 10                       Other             37868
# 11              Transportation            9203.8
# 12                 Social Life           2513.72
# 13                   Household             12188
# 14                     Apparel              3388
# 15                   Education              1400
# 16                      Salary              8000
# 17                   Allowance             14000
# 18                      Beauty               196
# 19                        Gift               115
# 20                  Petty cash                 3
# 21
# 22
# 23    Available for investment             -4270
# 24
# 25
# 26          Investment Profile  High Risk Taking

# %%
df2.head(2)
# Out:
# 0            Date               Account Category Subcategory  \
# 1  3/2/2022 10:11  CUB - online payment     Food
# 2  3/2/2022 10:11  CUB - online payment    Other
#
# 0              Note    INR Income/Expense Note Amount Currency Account
# 1           Brownie   50.0        Expense          50      INR      50
# 2  To lended people  300.0        Expense         300      INR     300

# %%
df2.dtypes
# Out:
# 0
# Date               object
# Account            object
# Category           object
# Subcategory        object
# Note               object
# INR               float64
# Income/Expense     object
# Note               object
# Amount             object
# Currency           object
# Account            object
# dtype: object

# %%
df2["INR"]
# Out:
# 1        50.0
# 2       300.0
# 3        78.0
# 4        30.0
# 5        67.0
#         ...
# 273      90.0
# 274      97.0
# 275     130.0
# 276     875.0
# 277    2000.0
# Name: INR, Length: 277, dtype: float64

# %%
Food = df2[df2['Category']=='Food']["INR"].sum()
Food
# Out:
# 24502.48

# %%
Other = df2[df2['Category']=='Other']["INR"].sum()
Other
# Out:
# 37868.0

# %%
Transportation = df2[df2['Category']=='Transportation']["INR"].sum()
Transportation
# Out:
# 9203.8

# %%
Social_Life = df2[df2['Category']=='Social Life']["INR"].sum()
Social_Life
# Out:
# 2513.7200000000003

# %%
Household = df2[df2['Category']=='Household']["INR"].sum()
Household
# Out:
# 12188.0

# %%
Apparel = df2[df2['Category']=='Apparel']["INR"].sum()
Apparel
# Out:
# 3388.0

# %%
Education = df2[df2['Category']=='Education']["INR"].sum()
Education
# Out:
# 1400.0

# %%
Salary = df2[df2['Category']=='Salary']["INR"].sum()
Salary
# Out:
# 8000.0

# %%
Allowance = df2[df2['Category']=='Allowance']["INR"].sum()
Allowance
# Out:
# 14000.0

# %%
Beauty = df2[df2['Category']=='Beauty']["INR"].sum()
Beauty
# Out:
# 196.0

# %%
Gift = df2[df2['Category']=='Gift']["INR"].sum()
Gift
# Out:
# 115.0

# %%
Petty_Cash = df2[df2['Category']=='Petty cash']["INR"].sum()
Petty_Cash
# Out:
# 3.0

# %%
# Category wise expense 
Category_wise_expense = df2.groupby('Category',as_index = False)['INR'].sum()
Category_wise_expense
# Out:
# 0           Category       INR
# 0          Allowance  14000.00
# 1            Apparel   3388.00
# 2             Beauty    196.00
# 3          Education   1400.00
# 4               Food  24502.48
# 5               Gift    115.00
# 6          Household  12188.00
# 7              Other  37868.00
# 8         Petty cash      3.00
# 9             Salary   8000.00
# 10  Self-development    400.00
# 11       Social Life   2513.72
# 12    Transportation   9203.80

# %%
# Category_wise_expense Chart

plt.figure(figsize = (22,9))
sns.barplot(Category_wise_expense['Category'],Category_wise_expense['INR'])
# Out:
# C:\Users\Suman Kumar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='INR'>

# %%
# Available_for_investment 

Available_for_investment = Net_income - Net_expense
Available_for_investment
# Out:
# -4270.0

# %%
# Task 1 conclusion 

# Here Available_for_investment amount is negative so investor has no money to invest beacuse investor more expense 
# than his income so investor is in debt.

# %%
# Task 2

# Suggest companies which are available for the investment on different basis of risk with their various filters
# like (i) High-risk companies
# (ii) Risk taking companies
#  (iii) Moderate risk companies
#  (iv) Low Risk companies    and update cell values of google sheet showing companies on different risks

# %%
# Our Available_for_investment amount is negative so we can't invest in any column

# %%
gsheet_name = 'Copy of Final Report'
tab_name = 'Sheet1'
def write_data(gsheet_name,tab_name):
    gc = gs.service_account(filename="my.json")
    sh = gc.open(gsheet_name)
    worksheet = sh.worksheet(tab_name)
    worksheet.update('C7',Net_income)
    worksheet.update('C8',Net_expense)
    worksheet.update('C10',Food)
    worksheet.update('C11',Other)
    worksheet.update('C12',Transportation)
    worksheet.update('C13',Social_Life)
    worksheet.update('C14',Household)
    worksheet.update('C15',Apparel)
    worksheet.update('C16',Education)
    worksheet.update('C17',Salary)
    worksheet.update('C18',Allowance)
    worksheet.update('C19',Beauty)
    worksheet.update('C20',Gift)
    worksheet.update('C21',Petty_Cash)
    
    worksheet.update('C24',Available_for_investment)
    
    
    

write_data(gsheet_name,tab_name)

# %%
# # establish a connection with google sheet
# final_report = gc.open('Copy of Final Report')
# final_report

# %%
# # selecting a worksheet

# wks = final_report.worksheet('Sheet1')
# wks

# %%
# wk= final_report.worksheet('Sheet2')
# wk

# %%
# list all the worksheets

# lists = final_report.worksheets()
# lists

# %%
# High_risk_company.head(1)

# %%
# wks.cell(27,3).value
# Out:
# 'High Risk Taking'

# %%
df
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# 0    INE058A01010        Healthcare                 Drugs & Pharma
# 1    INE761H01022          Textiles             Readymade Garments
# 2    INE179A01014  Consumer Staples  Household & Personal Products
# 3    INE358A01014        Healthcare                 Drugs & Pharma
# 4    INE323A01026        Automobile               Auto Ancillaries
# ..            ...               ...                            ...
# 496  INE274F01020          Services                    Restaurants
# 497  INE049B01025        Healthcare                 Drugs & Pharma
# 498  INE528G01035         Financial                        Banking
# 499  INE758T01015          Services                     E-Commerce
# 500  IN9155A01020        Automobile            Commercial Vehicles
#
#            Date     Price  1 day change(%)  52 Week Low  ...  \
# 0    2022-09-05   6158.70             0.59      6086.30  ...
# 1    2022-09-05  49786.20            -0.26     31500.00  ...
# 2    2022-09-05  14125.65             0.24     12801.00  ...
# 3    2022-09-05  18209.00            -1.26     15514.00  ...
# 4    2022-09-05  17591.10             0.13     12932.45  ...
# ..          ...       ...              ...          ...  ...
# 496  2022-09-05    650.05             0.82       402.30  ...
# 497  2022-09-05    242.70             3.01       201.50  ...
# 498  2022-09-05     16.65             2.78        10.80  ...
# 499  2022-09-05     59.65            -0.17        40.60  ...
# 500  2022-09-05    227.80            -0.96       137.50  ...
#
#      Price earnings to growth  Dividend Yield(%)  EV / EBITDA  Price / Sales  \
# 0                        0.49               7.95        16.68           4.98
# 1                        3.63               0.74        51.79          11.75
# 2                       13.56               1.13        52.71          12.10
# 3                        1.81               1.51        30.98           7.73
# 4                       -5.80               1.19        25.04           4.03
# ..                        ...                ...          ...            ...
# 496                      3.85               0.00        34.06           7.81
# 497                       NaN               0.00        20.50           1.18
# 498                     15.58               0.00        23.87           2.13
# 499                       NaN               0.00       -40.17          10.71
# 500                       NaN               0.00          NaN            NaN
#
#      Price / Cash Flow  Earning Per Share  Book Value Per Share  \
# 0                25.39             425.09                631.65
# 1               169.84             656.83               1161.63
# 2                53.17             177.37                227.22
# 3                40.84             380.52               1403.00
# 4               192.66             438.11               3734.33
# ..                 ...                ...                   ...
# 496              59.43               3.55                 30.99
# 497               8.48             -20.70                260.73
# 498               1.77               0.47                 13.61
# 499             -73.58              -1.21                 23.01
# 500                NaN                NaN                   NaN
#
#      Cash Flow Per Share  Free Cash Flow Per Share  Dividend Per Share
# 0                 242.96                    459.22               490.0
# 1                 293.09                    191.03               370.0
# 2                 265.90                    270.47               315.0
# 3                 445.96                    446.90               275.0
# 4                  91.29                     46.68               210.0
# ..                   ...                       ...                 ...
# 496                10.94                      1.29                 0.0
# 497                28.68                      8.54                 0.0
# 498                 9.42                      7.86                 0.0
# 499                -0.91                     -1.16                 0.0
# 500                  NaN                       NaN                 NaN
#
# [501 rows x 41 columns]

# %%
# inserting delta column

df['Delta']=(df['52 Week High']-df['Price'])/df['52 Week High']

# %%
df.head(2)
# Out:
#                 Company  BSE code NSE code          ISIN      Sector  \
# 0     Sanofi India Ltd.    500674   SANOFI  INE058A01010  Healthcare
# 1  Page Industries Ltd.    532827  PAGEIND  INE761H01022    Textiles
#
#              Industry        Date    Price  1 day change(%)  52 Week Low  ...  \
# 0      Drugs & Pharma  2022-09-05   6158.7             0.59       6086.3  ...
# 1  Readymade Garments  2022-09-05  49786.2            -0.26      31500.0  ...
#
#    Dividend Yield(%)  EV / EBITDA  Price / Sales  Price / Cash Flow  \
# 0               7.95        16.68           4.98              25.39
# 1               0.74        51.79          11.75             169.84
#
#    Earning Per Share  Book Value Per Share  Cash Flow Per Share  \
# 0             425.09                631.65               242.96
# 1             656.83               1161.63               293.09
#
#    Free Cash Flow Per Share  Dividend Per Share     Delta
# 0                    459.22               490.0  0.279073
# 1                    191.03               370.0  0.033278
#
# [2 rows x 42 columns]

# %%
#1 high risk taking companies
High_risk_company = df[(df['Delta']>0) & (df['Market Cap(Cr)']<2000) & (df['10-Year Return(%)']<8)]
High_risk_company
# Out:
# Empty DataFrame
# Columns: [Company, BSE code, NSE code, ISIN, Sector, Industry, Date, Price, 1 day change(%), 52 Week Low, 52 Week High, 3 Year Low, 3 Year High, 5 Year Low, 5 Year High, All Time Low, All Time High, Market Cap(Cr), Enterprise Value(Cr), 1-Week Return, 1-Month Return, 3-Month Return(%), 1-Year Return(%), 3-Year Return, 5-Year Return(%), 10-Year Return(%), Price to Earnings, Median P/E, Price to Book, Median P/B, Earning Yield(%), Price earnings to growth, Dividend Yield(%), EV / EBITDA, Price / Sales, Price / Cash Flow, Earning Per Share, Book Value Per Share, Cash Flow Per Share, Free Cash Flow Per Share, Dividend Per Share, Delta]
# Index: []
#
# [0 rows x 42 columns]

# %%
#2 risk taking

Risk_taking_company = df[(df['Delta']>0) & (df['Market Cap(Cr)'].between(2000,5000)) & (df['10-Year Return(%)'].between(8,15))].sort_values(['Dividend Per Share'],ascending = False)
Risk_taking_company
# Out:
#                  Company  BSE code    NSE code          ISIN  \
# 320             NCC Ltd.    500294         NCC  INE868B01028
# 325     Tata Coffee Ltd.    532301  TATACOFFEE  INE493A01027
# 396  Greaves Cotton Ltd.    501455  GREAVESCOT  INE224A01026
# 430             FDC Ltd.    531599         FDC  INE258B01022
#
#                Sector        Industry        Date   Price  1 day change(%)  \
# 320      Construction    Construction  2022-09-05   74.20            -0.13
# 325  Consumer Staples    Tea & Coffee  2022-09-05  243.10            -0.57
# 396     Capital Goods  Diesel Engines  2022-09-05  175.10             0.29
# 430        Healthcare  Drugs & Pharma  2022-09-05  280.25             2.43
#
#      52 Week Low  ...  Dividend Yield(%)  EV / EBITDA  Price / Sales  \
# 320        52.20  ...               2.70         4.44           0.38
# 325       181.65  ...               0.82        11.41           1.82
# 396       129.05  ...               0.11        34.08           1.89
# 430       225.00  ...               0.00        13.88           2.94
#
#      Price / Cash Flow  Earning Per Share  Book Value Per Share  \
# 320               3.29               8.95                 92.65
# 325              31.66               8.79                 84.80
# 396             -64.59               0.14                 32.92
# 430              28.68              11.41                122.18
#
#      Cash Flow Per Share  Free Cash Flow Per Share  Dividend Per Share  \
# 320                23.21                     15.82                 2.0
# 325                 7.67                      2.44                 2.0
# 396                -2.71                     -5.35                 0.2
# 430                 9.58                      5.88                 0.0
#
#         Delta
# 320  0.152000
# 325  0.044418
# 396  0.323677
# 430  0.246640
#
# [4 rows x 42 columns]

# %%
#3 Moderate risk taking
Moderate_risk_company = df[(df['Delta']>0) & (df['Market Cap(Cr)'].between(5000,15000)) & (df['10-Year Return(%)'].between(15,20))].sort_values(['Dividend Per Share']
                                                                                                                 ,ascending = False).head(5)
Moderate_risk_company
# Out:
#                                   Company  BSE code    NSE code          ISIN  \
# 64                            Cyient Ltd.    532175      CYIENT  INE136B01020
# 129                Birla Corporation Ltd.    500335  BIRLACORPN  INE340A01012
# 131                   Graphite India Ltd.    509488    GRAPHITE  INE371A01025
# 151                         Symphony Ltd.    517385    SYMPHONY  INE225D01027
# 163  Chambal Fertilisers & Chemicals Ltd.    500085  CHAMBLFERT  INE085A01013
#
#                      Sector                 Industry        Date    Price  \
# 64               Technology                 Software  2022-09-05   835.20
# 129               Materials                   Cement  2022-09-05  1005.05
# 131           Capital Goods             Refractories  2022-09-05   408.45
# 151  Consumer Discretionary      ACs & Refrigerators  2022-09-05   925.25
# 163               Chemicals  Nitrogenous Fertilizer.  2022-09-05   345.65
#
#      1 day change(%)  52 Week Low  ...  Dividend Yield(%)  EV / EBITDA  \
# 64              0.08        720.0  ...               2.87         8.65
# 129             3.74        823.0  ...               1.00         9.62
# 131             0.53        350.0  ...               2.45        10.80
# 151            -0.81        828.0  ...               0.97        27.78
# 163            -0.04        260.8  ...               2.17         7.72
#
#      Price / Sales  Price / Cash Flow  Earning Per Share  \
# 64            1.95              14.54              47.38
# 129           0.98               5.83              41.43
# 131           2.43             -16.32              19.40
# 151           5.69             113.88              20.44
# 163           0.73            -593.74              36.67
#
#      Book Value Per Share  Cash Flow Per Share  Free Cash Flow Per Share  \
# 64                 290.52                57.47                     50.05
# 129                793.55               172.50                     23.02
# 131                254.42               -25.03                    -11.36
# 151                124.14                 8.13                      8.51
# 163                161.25                -0.58                    -16.73
#
#      Dividend Per Share     Delta
# 64                 24.0  0.353560
# 129                10.0  0.390879
# 131                10.0  0.382073
# 151                 9.0  0.238477
# 163                 7.5  0.330136
#
# [5 rows x 42 columns]

# %%
# low risk taking

Low_risk_company = df[(df['Delta']>0) & (df['Market Cap(Cr)']>15000) & (df['10-Year Return(%)']>20)].sort_values(['Dividend Per Share'],
                                                                                              ascending = False).head()
Low_risk_company
# Out:
#                              Company  BSE code    NSE code          ISIN  \
# 1               Page Industries Ltd.    532827     PAGEIND  INE761H01022
# 3                  Abbott India Ltd.    500488  ABBOTINDIA  INE358A01014
# 8                           MRF Ltd.    500290         MRF  INE883A01011
# 13  Bajaj Holdings & Investment Ltd.    500490  BAJAJHLDNG  INE118A01012
# 16   Honeywell Automation India Ltd.    517174      HONAUT  INE671A01010
#
#            Sector               Industry        Date     Price  \
# 1        Textiles     Readymade Garments  2022-09-05  49786.20
# 3      Healthcare         Drugs & Pharma  2022-09-05  18209.00
# 8      Automobile          Tyres & Tubes  2022-09-05  84254.05
# 13      Financial    Investment Services  2022-09-05   5672.75
# 16  Capital Goods  Electronic Components  2022-09-05  41954.05
#
#     1 day change(%)  52 Week Low  ...  Dividend Yield(%)  EV / EBITDA  \
# 1             -0.26     31500.00  ...               0.74        51.79
# 3             -1.26     15514.00  ...               1.51        30.98
# 8             -0.12     63000.00  ...               0.18        15.57
# 13             0.40      4231.25  ...               2.03       176.36
# 16            -0.59     30185.35  ...               0.21        66.82
#
#     Price / Sales  Price / Cash Flow  Earning Per Share  Book Value Per Share  \
# 1           11.75             169.84             656.83               1161.63
# 3            7.73              40.84             380.52               1403.00
# 8            1.72             -61.82            1478.99              33376.26
# 13         163.59              39.22             381.55               3853.51
# 16          12.14             140.56             395.37               3313.31
#
#     Cash Flow Per Share  Free Cash Flow Per Share  Dividend Per Share  \
# 1                293.09                    191.03               370.0
# 3                445.96                    446.90               275.0
# 8              -1363.28                  -5522.36               150.0
# 13               144.64                     29.02               115.0
# 16               298.17                    384.59                90.0
#
#        Delta
# 1   0.033278
# 3   0.239214
# 8   0.058613
# 13  0.140232
# 16  0.114893
#
# [5 rows x 42 columns]

# %%
# cell_list = wk.range('B2:B8')
# cell_value = Low_risk_company.Company
    
# for i,val in enumerate(cell_value):
#     if wks.cell(27,3).value == 'Low Risk Taking':
#         cell_list[i].value = val
# wk.update_cells(cell_list)

# %%
# Assigning Values that got in high risk companies to variables 
# Variables For Companies
A = "No Company"
B = "No Company"
C = "No Company"
D = "No Company"
E = "No Company"
a=' '
b=' '
if Available_for_investment>0:
    high_risk_amount = Available_for_investment/len(High_risk_company.index)
else:
    high_risk_amount = 0

# Variables for Amounts
AA = high_risk_amount
BB = high_risk_amount
CC = high_risk_amount
DD = high_risk_amount
EE = high_risk_amount
aa =' '
bb =' '

# %%
# Assigning Values that got in  risk companies to variables 
# Variables For Companies
F = 'NCC Ltd.'
G = 'Tata Coffee Ltd'
H = 'Greaves Cotton Ltd.'
I = 'FDC Ltd.'
J = ' '
f=' '
g=' '
if Available_for_investment>0:
    risk_amount = Available_for_investment/len(Risk_taking_company.index)
else:
    risk_amount = 0
# Variables for Amounts
FF = risk_amount
GG = risk_amount
HH = risk_amount
II = risk_amount
JJ = ' '
ff=' '
gg=' '

# %%
# Assigning Values that got in Moderate risk companies to variables 
# Variables For Companies
K = 'Cyient Ltd.'
L = 'Birla Corporation Ltd.'
M = 'Graphite India Ltd.'
N = 'Symphony Ltd.'
O = 'Chambal Fertilisers & Chemicals Ltd.'
k=' '
l=' '

if Available_for_investment>0:
    Moderate_risk_amount = Available_for_investment/len(Moderate_risk_company.index)
else:
    Moderate_risk_amount = 0

# Variables for Amounts

KK = Moderate_risk_amount
LL = Moderate_risk_amount
MM = Moderate_risk_amount
NN= Moderate_risk_amount
OO= Moderate_risk_amount
kk=' '
ll=' '

# %%
# Assigning Values that got in Low risk companies to variables 
# Variables For Companies
P = 'Page Industries Ltd.'
Q = 'Abbott India Ltd.'
R = 'MRF Ltd.'
S = 'Bajaj Holdings & Investment Ltd.'
T = 'Honeywell Automation India Ltd.'
p=' '
q=' '

if Available_for_investment>0:
    low_risk_amount = Available_for_investment/len(Low_risk_company.index)
else:
    low_risk_amount = 0

# Variables for Amounts

PP = low_risk_amount
QQ = low_risk_amount
RR = low_risk_amount
SS = low_risk_amount
TT = low_risk_amount
pp=' '
qq=' '

# %%
# Updating Above Data in  Final report google sheet google sheets
gc = gs.service_account(filename="my.json")
sh = gc.open('Copy of Final Report')
worksheet1=sh.worksheet("Sheet1")
worksheet2=sh.worksheet("Sheet2")

C27= worksheet1.acell('C27').value
C27
if C27=='High Risk Taking':
    cell_list = worksheet2.range('B2:B8')
    cell_values = [A,B,C,D,E,a,b]

    for i,val in enumerate(cell_values):
        cell_list[i].value=val
    

    worksheet2.update_cells(cell_list)
    
    cell_list = worksheet2.range('C2:C8')  #Updating Amount in companies
    cell_values = [AA,BB,CC,DD,EE,aa,bb]

    for i,val in enumerate(cell_values):
        cell_list[i].value=val
    

    worksheet2.update_cells(cell_list)
    
elif C27=='Risk Taking':
    cell_list = worksheet2.range('B2:B8')
    cell_values = [F,G,H,I,J,f,g]

    for i,val in enumerate(cell_values):
        cell_list[i].value=val

    worksheet2.update_cells(cell_list)
    
    cell_list = worksheet2.range('C2:C8')
    cell_values = [FF,GG,HH,II,JJ,ff,gg]

    for i,val in enumerate(cell_values):
        cell_list[i].value=val

    worksheet2.update_cells(cell_list)
    
elif C27=='Moderate Risk Taking':
    cell_list = worksheet2.range('B2:B8')
    cell_values = [K,L,M,N,O,k,l]

    for i,val in enumerate(cell_values):
        cell_list[i].value=val

    worksheet2.update_cells(cell_list)
    
    cell_list = worksheet2.range('C2:C8')
    cell_values = [KK,LL,MM,NN,OO,kk,ll]

    for i,val in enumerate(cell_values):
        cell_list[i].value=val

    worksheet2.update_cells(cell_list)
    
elif C27=='Low Risk Taking':
    cell_list = worksheet2.range('B2:B8')
    cell_values = [P,Q,R,S,T,p,q]

    for i,val in enumerate(cell_values):
        cell_list[i].value=val

    worksheet2.update_cells(cell_list)
    
    cell_list = worksheet2.range('C2:C8')
    cell_values = [PP,QQ,RR,SS,TT,pp,qq]

    for i,val in enumerate(cell_values):
        cell_list[i].value=val

    worksheet2.update_cells(cell_list)

# %%
# Coclusion of Task 2

#  Finally I founded that 
# there no any High-risk company available for investment on the basis of the provided conditions 
# but there is few companies available for investment on the basis of Risks

# %%
# Task 3

# Compare the  median of column Enterprise Value(Cr) across different Sectors 
# Relation between dividend-per-share and market cap
# Count the companies in different Industry with positive and negative 3-Year Return so that I can suggest someone to invest
# in the particular company on the basis of the 3-years-return_% and those companies are performing well . I can seggest
# I can suggest someone to invest.
# suggest any 1 KPI to select best company for making investment

# %%
# Compare the median of column Enterprise Value(Cr) across different Sectors. For instance,
# what is the median enterprise value of Technology sector as compared to Services sector

med = df.groupby('Sector',as_index=False)['Enterprise Value(Cr)'].median()
med
# Out:
#                     Sector  Enterprise Value(Cr)
# 0               Automobile             35909.060
# 1            Capital Goods             12998.280
# 2                Chemicals             13704.380
# 3            Communication             42214.500
# 4             Construction             10062.270
# 5   Consumer Discretionary             13239.340
# 6         Consumer Staples             16451.255
# 7              Diversified             24475.610
# 8                   Energy             63786.425
# 9                Financial             31462.740
# 10              Healthcare             13374.630
# 11               Insurance             73724.110
# 12               Materials             12834.115
# 13         Metals & Mining             16216.110
# 14                  Others             13393.370
# 15                Services              9644.630
# 16              Technology             15692.095
# 17                Textiles             10884.830

# %%
# Chart of Comparision in median of enterprise value(cr) across different sectors 

plt.figure(figsize = (36,12))
sns.barplot(med['Sector'],med['Enterprise Value(Cr)'])
# Out:
# C:\Users\Suman Kumar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sector', ylabel='Enterprise Value(Cr)'>

# %%
# Try to find a relation between Dividend Per Share with Market Cap(Cr)

df[['Dividend Per Share','Market Cap(Cr)']].corr()
# Out:
#                     Dividend Per Share  Market Cap(Cr)
# Dividend Per Share            1.000000        0.040371
# Market Cap(Cr)                0.040371        1.000000

# %%
# Count the companies in different Industry with positive and negative 3-Year Return.
# For instance how many companies in Drugs & Pharma industry have positive 3-Year Return and how many have that negative.
# Basis this, decide which industry would you recommend someone to invest if the same return is followed

df.groupby(['Industry','3-Year Return'],as_index = False)['Company'].count()
# Out:
#                 Industry  3-Year Return  Company
# 0    ACs & Refrigerators          -9.02        1
# 1    ACs & Refrigerators          -0.18        1
# 2    ACs & Refrigerators           3.27        1
# 3    ACs & Refrigerators          16.27        1
# 4    ACs & Refrigerators          16.67        1
# ..                   ...            ...      ...
# 446    Welding machinery          49.60        1
# 447       Wires & cables           8.22        1
# 448       Wires & cables          46.14        1
# 449       Wires & cables          60.58        1
# 450                 Wood          72.33        1
#
# [451 rows x 3 columns]

# %%
#Then I also got the companies of different Industry which are performing positively and negatively in past 3_years

positive_3Years_retrn=df[df['3-Year Return']> 0].groupby(['Industry','3-Year Return','Company'],as_index = False)['Company'].sum()
positive_3Years_retrn
# Out:
#                 Industry  3-Year Return                         Company
# 0    ACs & Refrigerators           3.27         Whirlpool Of India Ltd.
# 1    ACs & Refrigerators          16.27                  Blue Star Ltd.
# 2    ACs & Refrigerators          16.67                     Voltas Ltd.
# 3    ACs & Refrigerators          40.77    Amber Enterprises India Ltd.
# 4              Abrasives          44.83      Carborundum Universal Ltd.
# ..                   ...            ...                             ...
# 396    Welding machinery          49.60                 Esab India Ltd.
# 397       Wires & cables           8.22             Finolex Cables Ltd.
# 398       Wires & cables          46.14             KEI Industries Ltd.
# 399       Wires & cables          60.58              Polycab India Ltd.
# 400                 Wood          72.33  Century Plyboards (India) Ltd.
#
# [401 rows x 3 columns]

# %%
negative_3Years_retrn=df[df['3-Year Return']< 0].groupby(['Industry','3-Year Return','Company'],as_index = False)['Company'].sum()
negative_3Years_retrn
# Out:
#                          Industry  3-Year Return  \
# 0             ACs & Refrigerators          -9.02
# 1             ACs & Refrigerators          -0.18
# 2                   Air Transport         -29.76
# 3      Asset Management Companies          -8.04
# 4                Auto Ancillaries          -4.05
# 5                         Banking         -34.57
# 6                         Banking         -27.45
# 7                         Banking         -15.84
# 8                         Banking         -14.37
# 9                         Banking          -8.55
# 10                        Banking          -7.28
# 11                        Banking          -7.21
# 12                        Banking          -6.42
# 13                        Banking          -5.61
# 14                        Banking          -2.47
# 15                         Cement          -1.80
# 16        Communication Equipment          -6.99
# 17                   Construction         -12.07
# 18                   Construction         -11.25
# 19                 Drugs & Pharma          -9.57
# 20                 Drugs & Pharma          -4.48
# 21                 Drugs & Pharma          -4.16
# 22                 Drugs & Pharma          -3.43
# 23                 Drugs & Pharma          -0.99
# 24                     E-Commerce          -4.58
# 25                Food Processing          -0.69
# 26  Gems, Jewellery & Accessories          -5.00
# 27              General Insurance          -3.13
# 28  Household & Personal Products          -9.39
# 29                Housing Finance         -33.48
# 30                Housing Finance         -16.31
# 31            Lubricants & Grease          -1.88
# 32          Media & Entertainment         -10.95
# 33             Misc. Fin.services         -15.91
# 34             Misc. Fin.services          -4.39
# 35             Misc. Fin.services          -2.62
# 36             Misc. Fin.services          -1.87
# 37             Misc. Fin.services          -1.58
# 38          Natural Gas Utilities          -6.67
# 39     Oil Refineries & Marketing          -4.02
# 40     Oil Refineries & Marketing          -3.69
# 41     Oil Refineries & Marketing          -2.46
# 42                 Power Projects         -19.13
# 43                 Power Projects          -3.58
# 44                    Reinsurance          -9.06
# 45                     SIDCs/SFCs          -0.75
# 46              Storage Batteries          -4.67
# 47              Storage Batteries          -0.13
# 48               Telecom Services         -16.13
# 49               Tobacco Products          -2.86
#
#                                               Company
# 0                                       Symphony Ltd.
# 1   Johnson Controls - Hitachi Air Conditioning In...
# 2                                       SpiceJet Ltd.
# 3                  HDFC Asset Management Company Ltd.
# 4                             Varroc Engineering Ltd.
# 5                                       Yes Bank Ltd.
# 6                                       RBL Bank Ltd.
# 7                                Punjab National Bank
# 8                                   Bandhan Bank Ltd.
# 9                                  Punjab & Sind Bank
# 10                                      Bank Of India
# 11                                Union Bank Of India
# 12                                           UCO Bank
# 13                                 IndusInd Bank Ltd.
# 14                               City Union Bank Ltd.
# 15                       Heidelberg Cement India Ltd.
# 16                                  Indus Towers Ltd.
# 17                               Engineers India Ltd.
# 18                                Dilip Buildcon Ltd.
# 19                             Jubilant Pharmova Ltd.
# 20                        Strides Pharma Science Ltd.
# 21                                         Lupin Ltd.
# 22                              Aurobindo Pharma Ltd.
# 23                      Glenmark Pharmaceuticals Ltd.
# 24                                     Just Dial Ltd.
# 25                                Zydus Wellness Ltd.
# 26                                Rajesh Exports Ltd.
# 27                   The New India Assurance Co. Ltd.
# 28                                Gillette India Ltd.
# 29                    Indiabulls Housing Finance Ltd.
# 30                           PNB Housing Finance Ltd.
# 31                                 Castrol India Ltd.
# 32                 Zee Entertainment Enterprises Ltd.
# 33                  Edelweiss Financial Services Ltd.
# 34                            Manappuram Finance Ltd.
# 35                                  JM Financial Ltd.
# 36                          L&T Finance Holdings Ltd.
# 37                              Equitas Holdings Ltd.
# 38                                  Petronet LNG Ltd.
# 39                        Indian Oil Corporation Ltd.
# 40                  Bharat Petroleum Corporation Ltd.
# 41               Hindustan Petroleum Corporation Ltd.
# 42          Sterling and Wilson Renewable Energy Ltd.
# 43                  Kalpataru Power Transmission Ltd.
# 44        General Insurance Corporation of India Ltd.
# 45                                           REC Ltd.
# 46                          Amara Raja Batteries Ltd.
# 47                              Exide Industries Ltd.
# 48                       Hathway Cable & Datacom Ltd.
# 49                                VST Industries Ltd.

# %%
# Come up with any one KPI which can help define the best stock across different Sector, 
# you may need to learn a little bit of Finance for the same
ROCE
Its an filter to measure compounded annual growth
Its ROCE means Return on Capital Employed of 5 years = 15% to 20%

# %%
# Conclusion

# S0 there are 401 companies which have performed positively in different industries
# and 50 companies those are not performed well in various industries.....
#  and the relation between dividend_per_share and market_cap is that the large_cap companies are paying less dividend to
#  their shareHolder where are mid_cap companies are paying more means but large_cap investments are safest investment for investors
# and its unable to find 1 KPI which can suggest that it is a best stock....
# but (i) Roce of 5 years and market cap > 20,000 cr ......

# %%
pwd
# Out:
# 'C:\\Users\\Suman Kumar'
